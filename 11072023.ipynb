# %% [markdown]
# ### Hel

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### sdfasdfasdfasdfMsadfM

# %% [markdown]
# #### sfasdfasdfsadfsdafsadmmksamfkasd

# %% [markdown]
# ##### lol i ama aman

# %% [markdown]
# ## Lol i am aman kaushik

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### it is my name
# first_name = "aman"

# %%
first_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 first_name
#
# NameError: name 'first_name' is not defined

# %%
first_name = "aman kaushik"
first_name

# %%
first+name = "artificial"
first+name
